# %%
install.packages('mosaic')
install.packages('Deriv')
# Out:
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/srv/rlibs’
# (as ‘lib’ is unspecified)

# %%
library(mosaic)
library(Deriv)

options(repr.plot.width = 8, repr.plot.height = 12)

# %%
f0 <- function(x) 4
f0
# Out:
# function(x) 4

# %%
d0 <- Deriv(f0)
d0
# Out:
# function (x)
# 0

# %%
f1 <- function(x) 4*x
f1
# Out:
# function(x) 4*x

# %%
plot(f1,xlim=c(-1,6), ylim =c(0,25),lwd = 4, col='blue')
# Out:
# plot without title

# %%
d1 <- Deriv(f1)
d1
# Out:
# function (x)
# 4

# %%
f2 <- function(x) x^2
f2
# Out:
# function(x) x^2

# %%
plot(f2,xlim=c(-5,5), ylim =c(0,25),lwd = 4, col='blue')
# Out:
# plot without title

# %%
d2 <- Deriv(f2)
d2
# Out:
# function (x)
# 2 * x

# %%
plot(d2,xlim=c(-2,2), ylim =c(-5,5),lwd = 3, col='blue')
# Out:
# plot without title

# %%
makeFun(X)
# Out:
# Error in makeFun(X): object 'X' not found
# Traceback:
#
# 1. makeFun(X)

# %%
v_t <- function(t) 5 + t*(3*t -12)
v_t
# Out:
# function(t) 5 + t*(3*t -12)

# %%
acc <- Deriv(v_t)
acc
# Out:
# function (t)
# 6 * t - 12

# %%
acc(5)
# Out:
# [1] 18

# %%
plot(acc,xlim= range(-2,8), ylim =range(-18,25),lwd = 3, col='red' , ylab = "Acceleration" , xlab = "time",
    main="6*t -12")
# Out:
# Plot with title “6*t -12”
